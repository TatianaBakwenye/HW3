# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
# Models Libraries
from scipy import stats

# %%
# Retrieve path
path = os.getcwd()

# %%
# a) Load the data
df = pd.read_csv(path+"/sample_diabetes_mellitus_data.csv")
df.head()
# Out:
#    Unnamed: 0  encounter_id  hospital_id   age        bmi  elective_surgery  \
# 0           0        214826          118  68.0  22.732803                 0
# 1           1        246060           81  77.0  27.421875                 0
# 2           2        276985          118  25.0  31.952749                 0
# 3           3        262220          118  81.0  22.635548                 1
# 4           4        201746           33  19.0        NaN                 0
#
#    ethnicity gender  height hospital_admit_source  ... ventilated_apache  \
# 0  Caucasian      M   180.3                 Floor  ...                 0
# 1  Caucasian      F   160.0                 Floor  ...                 1
# 2  Caucasian      F   172.7  Emergency Department  ...                 0
# 3  Caucasian      F   165.1        Operating Room  ...                 1
# 4  Caucasian      M   188.0                   NaN  ...                 0
#
# ...

# %%
df.shape
# Out:
# (10000, 53)

# %%
# c. Remove those rows that contain NaN values in the columns: age, gender, ethnicity.
def drop_na(df, columns):
    df_drop = df.dropna(subset=columns)
    return df_drop

result_c = drop_na(df, ['age', 'gender', 'ethnicity'])
print(result_c.shape)
# Out:
# (9368, 53)

# %%
df.describe()
# Out:
#         Unnamed: 0   encounter_id   hospital_id          age          bmi  \
# count  10000.00000   10000.000000  10000.000000  9595.000000  8262.000000
# mean    4999.50000  212388.142800    103.047300    62.409693    29.776210
# std     2886.89568   38026.609268     30.924057    16.603704     8.374851
# min        0.00000  147009.000000      4.000000    16.000000    14.844926
# 25%     2499.75000  179460.000000     83.000000    53.000000    23.945379
# 50%     4999.50000  211995.500000    118.000000    64.000000    28.196655
# 75%     7499.25000  245350.250000    118.000000    75.000000    33.749859
# max     9999.00000  279000.000000    198.000000    89.000000    67.814990
#
#        elective_surgery       height        icu_id  pre_icu_los_days  \
# count      10000.000000  9840.000000  10000.000000      10000.000000
# mean           0.229200   169.902573    105.659500          0.638186
# std            0.420339    10.724366     17.855964          2.134813
# ...

# %%
# d. Fill NaN with the mean value of the column in the columns: height, weight.
def fill_na(df, columns):
    for item in columns:
        df_fill = df.fillna(df[item].mean())
    return df_fill

# %%
# it changes other variables as well - doublecheck
columns = ['height', 'weight']
result_d = fill_na(df, columns)
print(result_d.describe())
# Out:
#         Unnamed: 0   encounter_id   hospital_id           age           bmi  \
# count  10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    4999.50000  212388.142800    103.047300     63.368951     39.564432
# std     2886.89568   38026.609268     30.924057     16.920967     22.659322
# min        0.00000  147009.000000      4.000000     16.000000     14.844926
# 25%     2499.75000  179460.000000     83.000000     53.000000     24.928590
# 50%     4999.50000  211995.500000    118.000000     65.000000     30.150017
# 75%     7499.25000  245350.250000    118.000000     77.000000     41.015732
# max     9999.00000  279000.000000    198.000000     89.000000     86.095094
#
#        elective_surgery        height        icu_id  pre_icu_los_days  \
# count      10000.000000  10000.000000  10000.000000      10000.000000
# mean           0.229200    168.561653    105.659500          0.638186
# std            0.420339     14.958735     17.855964          2.134813
# ...

# %%
df3 = pd.DataFrame(data3)

# Apply one-hot encoding
encoder = OneHotEncoder()
encoded_data = encoder.fit_transform(df3[['vehicle', 'marital_status']]).toarray()

# Convert the encoded data back to a dataframe
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out (['vehicle', 'marital_status']))


# Concatenate the encoded dataframe with the 'id' column
encoded_df = pd.concat([df3[['id', 'vehicle', 'marital_status']], encoded_df], axis=1)

print('\nDataframe3:')
display(encoded_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\bakwe\Documents\GitHub\Git extra\HW3\EX_6_Tatiana.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bakwe/Documents/GitHub/Git%20extra/HW3/EX_6_Tatiana.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df3 = pd.DataFrame(data3)
#       <a href='vscode-notebook-cell:/c%3A/Users/bakwe/Documents/GitHub/Git%20extra/HW3/EX_6_Tatiana.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> # Apply one-hot encoding
#       <a href='vscode-notebook-cell:/c%3A/Users/bakwe/Documents/GitHub/Git%20extra/HW3/EX_6_Tatiana.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> encoder = OneHotEncoder()
#
# NameError: name 'data3' is not defined

# %%
# e. Generate dummies for ethnicity column (One hot encoding).
def one_hot (df, columns):
    ncoder = OneHotEncoder()

# %%
# Extract the feature data (X) and the target variable (y) from your DataFrame
X = df.drop('diabetes_mellitus', axis=1)  # Replace 'target_column_name' with the name of your target variable
y = df['diabetes_mellitus']  # Replace 'target_column_name' with the name of your target variable

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
